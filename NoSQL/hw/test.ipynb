# %%
from pymongo import MongoClient

client = MongoClient()
db = client.movielens
ratings = db['ml_ratings']

# %%
ratings.create_index([('userId',1),('movieId',1)])
# Out:
# 'userId_1_movieId_1'

# %%
explaination = ratings.find({'userId':62986,'movieId':377}).explain()['executionStats']
explaination
# Out:
# {'executionSuccess': True,
#  'nReturned': 1,
#  'executionTimeMillis': 6,
#  'totalKeysExamined': 1,
#  'totalDocsExamined': 1,
#  'executionStages': {'stage': 'FETCH',
#   'nReturned': 1,
#   'executionTimeMillisEstimate': 0,
#   'works': 2,
#   'advanced': 1,
#   'needTime': 0,
#   'needYield': 0,
#   'saveState': 0,
#   'restoreState': 0,
#   'isEOF': 1,
#   'docsExamined': 1,
#   'alreadyHasObj': 0,
#   'inputStage': {'stage': 'IXSCAN',
#    'nReturned': 1,
#    'executionTimeMillisEstimate': 0,
#    'works': 2,
#    'advanced': 1,
#    'needTime': 0,
#    'needYield': 0,
#    'saveState': 0,
#    'restoreState': 0,
#    'isEOF': 1,
#    'keyPattern': {'userId': 1, 'movieId': 1},
#    'indexName': 'userId_1_movieId_1',
#    'isMultiKey': False,
#    'multiKeyPaths': {'userId': [], 'movieId': []},
#    'isUnique': False,
#    'isSparse': False,
#    'isPartial': False,
#    'indexVersion': 2,
#    'direction': 'forward',
# ...

# %%
explaination = ratings.find({'userId':62986,'movieId':377}).explain()['executionStats']
explaination
# Out:
# {'executionSuccess': True,
#  'nReturned': 1,
#  'executionTimeMillis': 0,
#  'totalKeysExamined': 1,
#  'totalDocsExamined': 1,
#  'executionStages': {'stage': 'FETCH',
#   'nReturned': 1,
#   'executionTimeMillisEstimate': 0,
#   'works': 3,
#   'advanced': 1,
#   'needTime': 0,
#   'needYield': 0,
#   'saveState': 0,
#   'restoreState': 0,
#   'isEOF': 1,
#   'docsExamined': 1,
#   'alreadyHasObj': 0,
#   'inputStage': {'stage': 'IXSCAN',
#    'nReturned': 1,
#    'executionTimeMillisEstimate': 0,
#    'works': 2,
#    'advanced': 1,
#    'needTime': 0,
#    'needYield': 0,
#    'saveState': 0,
#    'restoreState': 0,
#    'isEOF': 1,
#    'keyPattern': {'userId': 1, 'movieId': 1},
#    'indexName': 'userId_1_movieId_1',
#    'isMultiKey': False,
#    'multiKeyPaths': {'userId': [], 'movieId': []},
#    'isUnique': False,
#    'isSparse': False,
#    'isPartial': False,
#    'indexVersion': 2,
#    'direction': 'forward',
# ...

# %%
with open('res.txt','w') as f:
    f.write(str(explaination))

# %%
explaination
# Out:
# {'executionSuccess': True,
#  'nReturned': 1,
#  'executionTimeMillis': 0,
#  'totalKeysExamined': 1,
#  'totalDocsExamined': 1,
#  'executionStages': {'stage': 'FETCH',
#   'nReturned': 1,
#   'executionTimeMillisEstimate': 0,
#   'works': 3,
#   'advanced': 1,
#   'needTime': 0,
#   'needYield': 0,
#   'saveState': 0,
#   'restoreState': 0,
#   'isEOF': 1,
#   'docsExamined': 1,
#   'alreadyHasObj': 0,
#   'inputStage': {'stage': 'IXSCAN',
#    'nReturned': 1,
#    'executionTimeMillisEstimate': 0,
#    'works': 2,
#    'advanced': 1,
#    'needTime': 0,
#    'needYield': 0,
#    'saveState': 0,
#    'restoreState': 0,
#    'isEOF': 1,
#    'keyPattern': {'userId': 1, 'movieId': 1},
#    'indexName': 'userId_1_movieId_1',
#    'isMultiKey': False,
#    'multiKeyPaths': {'userId': [], 'movieId': []},
#    'isUnique': False,
#    'isSparse': False,
#    'isPartial': False,
#    'indexVersion': 2,
#    'direction': 'forward',
# ...
